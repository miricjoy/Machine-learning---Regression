# %%
#using seperate deployment python notebook 
import pickle

# %%
#load the saved model using pickle.load
model=pickle.load(open("finalised_model.sav","rb"))

# %%
#use predict function on test input - input "0" gives starting point -intercept value
model.predict([[0]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26777.3913412]])

# %%
#Get input from user
model.predict([[int(input("enter years of experience"))]])
# Out:
# enter years of experience 20
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[213982.61706507]])

# %%
import pickle
model=pickle.load(open("finalised_mul_model.sav","rb"))
model
# Out:
# LinearRegression()

# %%
a=[]
a.extend((input("Enter the values for R&D Spend,Administration,Marketing Spend,State_Florida, State_New York")).split())
#input received as string , use str.split()-split at space
a
# Out:
# Enter the values for R&D Spend,Administration,Marketing Spend,State_Florida, State_New York 10 10 10 1 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       3 #input received as string , use str.split()-split at space
#       4 a
# ----> 5 a.dtype
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
type(a)
# Out:
# list

# %%
model.predict([[a]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.predict([[a]])
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:269, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
#     267     check_is_fitted(self)
# ...
